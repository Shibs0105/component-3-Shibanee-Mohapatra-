# %%
import tech_startup_recruitment_data
# Out:
#    attrition  performance_rating  sales_quota_pct recruiting_source
# 0          1                   3         1.088190    Applied Online
# 1          0                   3         2.394173               NaN
# 2          1                   2         0.497530            Campus
# 3          0                   2         2.513958               NaN
# 4          0                   3         1.424789    Applied Online
# Index(['attrition', 'performance_rating', 'sales_quota_pct',
#        'recruiting_source'],
#       dtype='object')

# %%
import componet2
# Out:
# First few rows of the data:
#    attrition  performance_rating  sales_quota_pct recruiting_source
# 0          1                   3         1.088190    Applied Online
# 1          0                   3         2.394173               NaN
# 2          1                   2         0.497530            Campus
# 3          0                   2         2.513958               NaN
# 4          0                   3         1.424789    Applied Online
# Column names:
# Index(['attrition', 'performance_rating', 'sales_quota_pct',
#        'recruiting_source'],
#       dtype='object')
#
# Number of Candidates by Recruitment Source:
# recruiting_source
# Applied Online    130
# Campus             56
# Referral           45
# Search Firm        10
# Name: count, dtype: int64

# %%
import Average_Sales_Numbers_And_Attrition_Numbers
# Out:
# Average Sales Number and Attrition Number by Recruiting Source:
#                    sales_quota_pct  attrition
# recruiting_source
# Applied Online            1.058590   0.246154
# Campus                    0.908035   0.285714
# Referral                  1.023198   0.333333
# Search Firm               0.886960   0.500000
